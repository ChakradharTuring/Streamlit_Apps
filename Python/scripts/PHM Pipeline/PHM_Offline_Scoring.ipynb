# %% [markdown]
# ### Importing the Libraries
# In this section we will be importing the required libraries to work on creating PHM calculation based on the Offline FS.

# %%
import pandas as pd
import numpy as np
import datetime
import warnings
import ast
import pickle
import sys
from tqdm.auto import tqdm
import os
tqdm.pandas()
from pathlib import Path
import requests
import json
import config
from datetime import datetime

import os
warnings.filterwarnings("ignore")

from ranking_utility.use_cases.historical_feature_store_accessor_use_case import (
    HistoricalFeatureStoreAccessorUseCase,
)

from ranking_utility.features.utils import calculate_historical_features, calculate_features_on_subset
from ranking_utility.features import *

import sys
sys.path.append("../learning_better_ranking/vertex_ai_models/models/gbdt_ranker_v23")
import feature_engineering

# %% [markdown]
# ### Initializing Features
# In this section, we are creating a dictionary of features that are part of the ranking model to score the developers

# %%
features = [
    InterviewScore(),
    AtLeast1YOERatio(),
    MeanRelevantMCQPercentile(),
    MeanAggregateMCQPercentile(), # ["mean_mcq_pct"] < 61
    MaxSkillsYOE(),
    MaxRelevantMCQPercentile(),
    MinRelevantMCQPercentile(), # ["min_relevant_mcq_pct"] < 40
    SumRelevantProjectWords(),
    AtLeast2YOERatio(),
    AtLeast3YOERatio(),
    StartsInWeeks(),
    HourlyRate(),
    SeniorityAverage(),
    MaxAggregateMCQPercentile(),
    TIACCScore(),
    TILCIScore(),
    TIOOOScore(), # ["ti_ooo_score"] < 5
    CosineSimilarityJob(),
    CosineSimilarityQuery(),
    CosineSimilarityQueryFinetuned(),
    CosineSimilarityJobFinetuned(),
    # TIType
]

# %% [markdown]
# ### Skill - Challenges Mapping
# In this section we are retrieving all the skills with the challenge IDs which will be utilized later to get the skill keywords for the respective TupleIDs

# %%
def get_challenges():
    """
    returns a dict mapping skills to challenges
    """
    skill_det = pd.io.gbq.read_gbq(
    f"""
    SELECT
        mjs.skill_id,
        bas.skill_name,
        ARRAY_AGG(DISTINCT msc.challenge_id IGNORE NULLS) AS challenge_ids,
    FROM
        `raw.ms2_job_skill` mjs
    LEFT JOIN
        `raw.ms2_skill_challenges` msc
    ON
        mjs.skill_id = msc.skill_id
    LEFT JOIN
        `raw.base_all_skills_v4` bas
    ON
        mjs.skill_id = bas.id
    GROUP BY
      1,2
    """,project_id='turing-230020')
    
    challenge_map = {}
    name_map = {}
    for skill in skill_det.skill_id.values:
        challenge_map[skill] = skill_det[skill_det.skill_id == skill].challenge_ids.values[0]
        name_map[skill] = skill_det[skill_det.skill_id == skill].skill_name.values[0]

    return challenge_map, name_map

challenge_map, name_map = get_challenges()

# %% [markdown]
# ### Forecasted Jobs
# In this section we are collecting the forecasted jobs along with the respective TupleIDs and required skills.

# %%
# must have skills as a list of lists
job_skills = pd.io.gbq.read_gbq(
f"""
  WITH data_ AS (
    SELECT DISTINCT
      job_id, tupleId,  skill_name, CAST(s.id AS int64) AS skill_id
    FROM `turing-230020.product_ds_supply.forecasted_tuples_q4_2023_v0` , UNNEST(SPLIT(Skill_Tuple, '|'))skill_name 
    LEFT JOIN `turing-230020.raw.base_all_skills_v4` s USING(skill_name)
  )

    SELECT
      job_id, tupleId,
      `matchingmetrics`.structurize_skills(TO_JSON_STRING(ARRAY_AGG(DISTINCT skill_id
          ORDER BY
            skill_id))) AS skills
    FROM
      data_
    /*
    WHERE  
    tupleId IN (
      SELECT 
        DISTINCT tupleId 
      FROM `turing-230020.product_ds_supply.forecasted_tuples_q4_baseline_supply` 
      WHERE Prioritized_by_Fulfillment = 'Yes'
    )
    */
    GROUP BY
      job_id, tupleId
"""
,project_id='turing-230020')
job_skills
# Out:
#      job_id    tupleId                 skills
# 0     11836   11836_11          [[114],[189]]
# 1     15228  15228_247         [[268],[2091]]
# 2     12506   12506_44           [[54],[433]]
# 3     13510  13510_134                [[268]]
# 4     15325  15325_261                 [[61]]
# ..      ...        ...                    ...
# 317   15373  15373_271    [[69],[511],[2091]]
# 318   13619  13619_147    [[411],[559],[710]]
# 319   15272  15272_254  [[160],[1561],[1849]]
# 320   11585    11585_3     [[20],[108],[268]]
# 321   15211  15211_245  [[400],[1849],[2091]]
#
# [322 rows x 3 columns]

# %%
#Generating Skill keywords
job_skills.skills = job_skills.skills.map(ast.literal_eval)
job_skills['num_skills'] = job_skills.skills.map(len)
job_skills['g_skills'] = job_skills.skills.apply(lambda r: [[{"skillId":s,'keyword':name_map[s]} for s in skills] for skills in sorted(r)])
job_skills['keywords'] = job_skills.skills.apply(lambda r: [name_map[s] for skill in r for s in skill])
job_skills['skill_comb'] = job_skills.g_skills.apply(lambda r: str(r))

job_skills_dict = {job['job_id']:job['skills'] for id,job in job_skills.iterrows()}

# %%
outcome_jobs = list(job_skills.job_id.unique())

# %%
#job_skills = job_skills[0:1]

# %% [markdown]
# ### Must-Have Skill Retrieval
# Based on the must-have skills, need to retrieve developers from the Phase-2 Pool.

# %%
#Function Parameters
debug = False
all_features = False
retrieval_size = 50000
ranker_name = "No Ranking" # use "No Ranking" in case of no ranking
p1_or_p2 = "P2"

# %%
tqdm.monitor_interval = 0
resp = ""

results = pd.DataFrame({'tupleId':[], 'job_id':[],'dev_id':[],'score':[]})

for id,job in tqdm(job_skills.iterrows(),total=len(job_skills)):
    with requests.Session() as s:

        if p1_or_p2 == "P1":
            payload = json.load(open('p1_retrieval_payload_psl_retrieval.json', 'r'))
        if p1_or_p2 == "P2":
            payload = json.load(open('v20_api_payload_psl_retrieval.json', 'r'))


        
        payload['skillKeywordSearch']['mustHave'] = job['g_skills']

        payload['searchAnywhereParameters']['mustHaveWords'] = job['keywords']

        payload['jobId'] = job['job_id']#.astype(str)
        payload['hideACCCheater'] = True


        payload['featureFlags']['matching-ranker'] = ranker_name
        payload['pageSize'] = retrieval_size        
        payload['debug'] = debug
        

        json_payload = json.dumps(payload)
        content_length = str(len(json_payload))

        headers = {
            'Content-Type': 'application/json',
            'Content-Length': content_length,
            'authorization': config.bearer_token
        }

        resp = s.post(config.url, json_payload, headers = headers)
        try:
            
            if debug == False:
                resp_df = pd.DataFrame(json.loads(json.dumps(resp.json()['developers'])))
                resp_df.rename(columns = {'score' : 'score', 'userId':'dev_id'}, inplace = True)
                resp_df['dev_id'] = resp_df['dev_id'].astype(int)
                resp_df['score'] = resp_df['score'].astype(float)

            else:
                if all_features:
                    resp_df = pd.DataFrame([values for id, values in resp.json()['debug']['feature_df'].items()])
                    resp_df["dev_id"] = [id for id, values in resp.json()['debug']['feature_df'].items()]
                    resp_df.rename(columns = {'modelScore' : 'score'}, inplace = True)
                    


                else:
                    resp_df = pd.DataFrame([(id, values['modelScore']) for id, values in resp.json()['debug']['feature_df'].items()], columns=['dev_id', 'modelScore']) 
                    resp_df.rename(columns = {'modelScore' : 'score'}, inplace = True)
                    resp_df['dev_id'] = resp_df['dev_id'].astype(int)
                    resp_df['score'] = resp_df['score'].astype(float)
                
           


            resp_df['job_id'] = job['job_id']
            resp_df['tupleId'] = job['tupleId']
            
            #results = results.append(resp_df)
            results = pd.concat([results, resp_df], ignore_index=True)
            print(f"job: {job['job_id']} : Done")
        except Exception as e:
            print(e)
            print(f"job: {job['job_id']} : Error - {resp.status_code}: {resp.text}")
            continue
results.shape
# Out:
#   0%|          | 0/322 [00:00<?, ?it/s]
# job: 11836 : Done
# job: 15228 : Done
# job: 12506 : Done
# job: 13510 : Done
# job: 15325 : Done
# job: 12030 : Done
# job: 12842 : Done
# job: 12766 : Done
# job: 15278 : Done
# job: 15541 : Done
# job: 12622 : Done
# job: 12044 : Done
# job: 15258 : Done
# job: 12849 : Done
# job: 14986 : Done
# job: 15165 : Done
# job: 13666 : Done
# job: 11746 : Done
# job: 11825 : Done
# job: 12753 : Done
# job: 12458 : Done
# job: 12031 : Done
# job: 14996 : Done
# job: 15047 : Done
# job: 11940 : Done
# job: 15105 : Done
# job: 12773 : Done
# job: 15316 : Done
# job: 12036 : Done
# job: 12585 : Done
# job: 15542 : Done
# job: 12045 : Done
# job: 15174 : Done
# job: 13374 : Done
# job: 13016 : Done
# job: 14030 : Done
# job: 12236 : Done
# job: 13717 : Done
# job: 13367 : Done
# job: 14618 : Done
# job: 14685 : Done
# job: 12851 : Done
# job: 15679 : Done
# job: 14665 : Done
# job: 13226 : Done
# job: 15499 : Done
# job: 13227 : Done
# job: 15501 : Done
# job: 13045 : Done
# job: 13562 : Done
# job: 13193 : Done
# job: 11863 : Done
# job: 15138 : Done
# job: 15191 : Done
# job: 12954 : Done
# job: 15029 : Done
# job: 12620 : Done
# job: 12732 : Done
# job: 12890 : Done
# job: 12379 : Done
# job: 12883 : Done
# job: 15663 : Done
# job: 14128 : Done
# job: 15546 : Done
# job: 13576 : Done
# job: 13018 : Done
# job: 15247 : Done
# job: 15057 : Done
# job: 12328 : Done
# job: 15341 : Done
# job: 15078 : Done
# job: 15078 : Done
# job: 15078 : Done
# job: 12625 : Done
# job: 14274 : Done
# job: 13140 : Done
# job: 14857 : Done
# job: 14659 : Done
# job: 11809 : Done
# job: 13131 : Done
# job: 15434 : Done
# job: 15328 : Done
# job: 15326 : Done
# job: 13556 : Done
# job: 15018 : Done
# job: 12889 : Done
# job: 15177 : Done
# job: 11577 : Done
# job: 15516 : Done
# job: 12953 : Done
# job: 12058 : Done
# job: 13058 : Done
# job: 11910 : Done
# job: 13203 : Done
# job: 12519 : Done
# job: 14326 : Done
# job: 15495 : Done
# job: 12022 : Done
# job: 15155 : Done
# job: 13663 : Done
# job: 14697 : Done
# job: 15156 : Done
# job: 14196 : Done
# job: 15290 : Done
# job: 11583 : Done
# job: 12408 : Done
# job: 14854 : Done
# job: 15143 : Done
# job: 15267 : Done
# job: 12958 : Done
# job: 13743 : Done
# job: 13509 : Done
# job: 11820 : Done
# job: 12630 : Done
# job: 12000 : Done
# job: 15496 : Done
# job: 15379 : Done
# job: 15106 : Done
# job: 14881 : Done
# job: 13933 : Done
# job: 12073 : Done
# job: 14271 : Done
# job: 14570 : Done
# job: 12749 : Done
# job: 12956 : Done
# job: 13138 : Done
# job: 12847 : Done
# job: 12656 : Done
# job: 12309 : Done
# job: 13660 : Done
# job: 15443 : Done
# job: 13574 : Done
# job: 12569 : Done
# job: 13305 : Done
# job: 13013 : Done
# job: 13234 : Done
# job: 11677 : Done
# job: 15559 : Done
# job: 15555 : Done
# job: 13039 : Done
# job: 14874 : Done
# job: 13050 : Done
# job: 14905 : Done
# job: 12943 : Done
# job: 14576 : Done
# job: 14942 : Done
# job: 14577 : Done
# job: 15619 : Done
# job: 12104 : Done
# job: 15146 : Done
# job: 15146 : Done
# job: 13232 : Done
# job: 15649 : Done
# job: 15147 : Done
# job: 13571 : Done
# job: 15367 : Done
# job: 13943 : Done
# job: 11689 : Done
# job: 11846 : Done
# job: 13554 : Done
# job: 15563 : Done
# job: 15535 : Done
# job: 12715 : Done
# job: 12687 : Done
# job: 14846 : Done
# job: 15349 : Done
# job: 12245 : Done
# job: 13118 : Done
# job: 15185 : Done
# job: 14959 : Done
# job: 15627 : Done
# job: 15578 : Done
# job: 12689 : Done
# job: 12689 : Done
# job: 12818 : Done
# job: 15388 : Done
# job: 12485 : Done
# job: 12980 : Done
# job: 14851 : Done
# job: 14850 : Done
# job: 14713 : Done
# job: 13679 : Done
# job: 15229 : Done
# job: 15051 : Done
# job: 15532 : Done
# job: 15000 : Done
# job: 12767 : Done
# job: 15223 : Done
# job: 13539 : Done
# job: 12686 : Done
# job: 13163 : Done
# job: 14276 : Done
# job: 15613 : Done
# job: 15042 : Done
# job: 15166 : Done
# job: 15519 : Done
# job: 14883 : Done
# job: 12691 : Done
# job: 12690 : Done
# job: 15381 : Done
# job: 14668 : Done
# job: 14990 : Done
# job: 14924 : Done
# job: 15291 : Done
# 'dev_id'
# job: 12708 : Error - 201: {"uuid":"9906cdc2-b9c5-4f62-982b-ef0ddb1f9c9a","totalDevelopers":0,"totalPaginatedCount":0,"developers":[],"excludedDevelopers":[],"errors":{"totalRetrievalCalls":28,"totalRankingCalls":0,"retrievalErrors":0,"rankingErrors":0}}
# job: 12722 : Done
# job: 15289 : Done
# job: 11840 : Done
# job: 13833 : Done
# job: 12705 : Done
# job: 12866 : Done
# job: 14550 : Done
# job: 15396 : Done
# job: 15396 : Done
# job: 15396 : Done
# job: 15396 : Done
# job: 12306 : Done
# job: 15439 : Done
# job: 13056 : Done
# job: 15108 : Done
# job: 12961 : Done
# job: 15116 : Done
# job: 13328 : Done
# job: 15344 : Done
# job: 15044 : Done
# job: 13558 : Done
# job: 14869 : Done
# job: 12023 : Done
# job: 15176 : Done
# job: 15677 : Done
# job: 12525 : Done
# job: 12524 : Done
# job: 13568 : Done
# job: 13568 : Done
# job: 12760 : Done
# job: 12007 : Done
# job: 11826 : Done
# job: 12332 : Done
# job: 15028 : Done
# job: 12470 : Done
# job: 15396 : Done
# job: 15396 : Done
# job: 15396 : Done
# job: 14844 : Done
# job: 14964 : Done
# job: 15287 : Done
# job: 15621 : Done
# job: 15456 : Done
# job: 13144 : Done
# job: 14584 : Done
# job: 12752 : Done
# job: 13139 : Done
# job: 14587 : Done
# job: 15173 : Done
# job: 15568 : Done
# job: 15568 : Done
# job: 14656 : Done
# job: 12573 : Done
# job: 15356 : Done
# job: 14984 : Done
# job: 12528 : Done
# job: 13187 : Done
# job: 14447 : Done
# job: 14582 : Done
# job: 15369 : Done
# job: 13613 : Done
# job: 15485 : Done
# job: 12445 : Done
# job: 12973 : Done
# job: 13190 : Done
# job: 15512 : Done
# job: 12526 : Done
# job: 15354 : Done
# job: 15417 : Done
# job: 13365 : Done
# job: 13364 : Done
# 'dev_id'
# job: 12670 : Error - 201: {"uuid":"c0c69517-303f-4836-9cc2-78a971c1eaff","totalDevelopers":0,"totalPaginatedCount":0,"developers":[],"excludedDevelopers":[],"errors":{"totalRetrievalCalls":28,"totalRankingCalls":0,"retrievalErrors":0,"rankingErrors":0}}
# job: 13445 : Done
# job: 15083 : Done
# job: 12409 : Done
# job: 12523 : Done
# job: 13568 : Done
# job: 12916 : Done
# job: 12915 : Done
# job: 12914 : Done
# job: 13500 : Done
# 'dev_id'
# job: 14414 : Error - 201: {"uuid":"0de0745a-81e8-4860-a690-db1a8275263e","totalDevelopers":0,"totalPaginatedCount":0,"developers":[],"excludedDevelopers":[],"errors":{"totalRetrievalCalls":28,"totalRankingCalls":0,"retrievalErrors":0,"rankingErrors":0}}
# job: 13372 : Done
# job: 12880 : Done
# job: 12868 : Done
# job: 15428 : Done
# job: 15428 : Done
# job: 14532 : Done
# job: 12433 : Done
# job: 12756 : Done
# job: 15246 : Done
# job: 15271 : Done
# job: 15193 : Done
# job: 15193 : Done
# job: 15193 : Done
# job: 15188 : Done
# job: 13634 : Done
# job: 13636 : Done
# job: 15503 : Done
# job: 15503 : Done
# job: 15503 : Done
# job: 15503 : Done
# job: 15609 : Done
# job: 15103 : Done
# job: 12056 : Done
# job: 13698 : Done
# job: 15066 : Done
# job: 13635 : Done
# job: 15503 : Done
# job: 15503 : Done
# job: 13632 : Done
# job: 14970 : Done
# job: 15373 : Done
# job: 13619 : Done
# job: 15272 : Done
# job: 11585 : Done
# job: 15211 : Done
# (2598119, 4)

# %%
results.head(5)
# Out:
#     tupleId   job_id     dev_id      score
# 0  11836_11  11836.0  3784659.0  146.63704
# 1  11836_11  11836.0  1287973.0  145.76330
# 2  11836_11  11836.0  1868788.0  145.51804
# 3  11836_11  11836.0  3555220.0  141.64862
# 4  11836_11  11836.0  2060045.0  134.48859

# %%
results['job_id'] = results['job_id'].astype(int)
results['developer_id'] = results['dev_id'].astype(int)
results['score'] = results['score'].astype(float)

results.head()
# Out:
#     tupleId  job_id     dev_id      score  developer_id
# 0  11836_11   11836  3784659.0  146.63704       3784659
# 1  11836_11   11836  1287973.0  145.76330       1287973
# 2  11836_11   11836  1868788.0  145.51804       1868788
# 3  11836_11   11836  3555220.0  141.64862       3555220
# 4  11836_11   11836  2060045.0  134.48859       2060045

# %%
results.shape
# Out:
# (2598119, 5)

# %%
backfill_date = '2023-11-29'
results['Extraction_Date'] = backfill_date
# Need to add Extraction date column in results @Bhavesh

# %%
results.head(5)
# Out:
#     tupleId  job_id     dev_id      score  developer_id Extraction_Date
# 0  11836_11   11836  3784659.0  146.63704       3784659      2023-11-29
# 1  11836_11   11836  1287973.0  145.76330       1287973      2023-11-29
# 2  11836_11   11836  1868788.0  145.51804       1868788      2023-11-29
# 3  11836_11   11836  3555220.0  141.64862       3555220      2023-11-29
# 4  11836_11   11836  2060045.0  134.48859       2060045      2023-11-29

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2598119 entries, 0 to 2598118
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   tupleId          object
#  1   job_id           int64
#  2   dev_id           float64
#  3   score            float64
#  4   developer_id     int64
#  5   Extraction_Date  object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 118.9+ MB

# %%
all_outcomes = results.copy()
all_outcomes = job_skills.merge(all_outcomes,on=['tupleId', 'job_id'],how='left').fillna(0)
all_outcomes = all_outcomes.drop_duplicates(subset=['Extraction_Date', 'tupleId', 'job_id','developer_id'])
results_f = all_outcomes[['Extraction_Date', 'tupleId', 'job_id','developer_id']]
results_f.shape
# Out:
# (2598122, 4)

# %%
all_outcomes = results_f
all_outcomes['developer_id'] = all_outcomes['developer_id'].astype(int)
all_outcomes.head()
# Out:
#   Extraction_Date   tupleId  job_id  developer_id
# 0      2023-11-29  11836_11   11836       3784659
# 1      2023-11-29  11836_11   11836       1287973
# 2      2023-11-29  11836_11   11836       1868788
# 3      2023-11-29  11836_11   11836       3555220
# 4      2023-11-29  11836_11   11836       2060045

# %%
all_outcomes.shape
# Out:
# (2598122, 4)

# %% [markdown]
# ### Build Data-Set for the Offline Feature Store
# Need to build the above data-set, which can be used to generate the required features using the Offline FS.

# %%
# Ensure we found skills for the jobs we are looking at here
all_outcomes = all_outcomes[all_outcomes.job_id.isin(job_skills.job_id.unique())]

# %%
all_outcomes['Extraction_Date'] = all_outcomes['Extraction_Date'].astype(str)

# %%
all_outcomes['developer_id'] = all_outcomes['developer_id'].astype(int)

# %%
def get_outcomes_dataset(jd_df):
    jd_dict = {'tupleId':[], 'job_id':[],'developer_id':[],'feature_lookup_date':[],'skill_ids':[],'challenge_ids':[],'keywords':[],'timestamp':[]}

    for index, jd in tqdm(jd_df.iterrows(),total=len(jd_df)):
        skills = [set(s) for s in job_skills_dict[jd['job_id']]]

        jd_dict['job_id'].append(jd['job_id'])
        jd_dict['tupleId'].append(jd['tupleId'])
        jd_dict['developer_id'].append(jd['developer_id'])
        
        # change the timestamp here
        jd_dict['feature_lookup_date'] = jd_df['Extraction_Date']
#        jd_dict['feature_lookup_date'].append(pd.to_datetime(datetime.datetime.strptime(jd_df['Extraction_Date'], "%Y-%m-%d")))
        
        jd_dict['skill_ids'].append(skills)
        
        challenges = [[c for s in skill for c in challenge_map[s]] for skill in skills]
        challenges = [set(c) for c in challenges if len(c) > 0]
        jd_dict['challenge_ids'].append(challenges)
        
        jd_dict['keywords'].append([[name_map[s] for s in skill] for skill in skills])
        
        # change the timestamp here
        jd_dict['timestamp'] = jd_df['Extraction_Date']
#        jd_dict['timestamp'].append(pd.to_datetime(datetime.datetime.strptime(jd_df['Extraction_Date'], "%Y-%m-%d")))

    jd_df = pd.DataFrame(jd_dict)
    return jd_df

# %%
outcome_pairs_df = get_outcomes_dataset(all_outcomes)
# Out:
#   0%|          | 0/2598122 [00:00<?, ?it/s]

# %%
outcome_pairs_df.shape
# Out:
# (2598122, 8)

# %%
outcome_pairs_df.head()
# Out:
#     tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0  11836_11   11836       3784659          2023-11-29  [{114}, {189}]
# 1  11836_11   11836       1287973          2023-11-29  [{114}, {189}]
# 2  11836_11   11836       1868788          2023-11-29  [{114}, {189}]
# 3  11836_11   11836       3555220          2023-11-29  [{114}, {189}]
# 4  11836_11   11836       2060045          2023-11-29  [{114}, {189}]
#
#               challenge_ids            keywords   timestamp
# 0  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 1  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 2  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 3  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 4  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29

# %%
outcome_pairs_df.dtypes
# Out:
# tupleId                object
# job_id                  int64
# developer_id            int64
# feature_lookup_date    object
# skill_ids              object
# challenge_ids          object
# keywords               object
# timestamp              object
# dtype: object

# %%
import pandas_gbq
import time

fdf = None


class VAIFeatureGenerator:
    def __init__(self):
        self.accessor = HistoricalFeatureStoreAccessorUseCase()

    def __validate_df(self, df):
        for col in ["job_id", "developer_id", "timestamp", "skill_ids", "challenge_ids", "keywords"]:
            assert col in df.columns, f"{col} not present in df"

    def generate_features(self, df, features):

        self.__validate_df(df)


        start=time.time()
        
        response = self.accessor.fetch_features(
            pairs=df,
            features=features,
        )

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            feature_df = calculate_historical_features(
                data_df=df.copy(),
                features=features,
                feature_store_features=response,
            )

        print("Time taken", time.time() - start)

        return feature_df


    def generate_features_batch_ameer(self, df, features, batch_size=100000):
        num_batches = len(df) // batch_size + 1
        csv_file = 'features_hsitorical.csv'
        batch_file = 'last_batch.txt'
        if os.path.exists(batch_file):
            with open(batch_file, 'r') as f:
                start_batch = int(f.read())
        else:
            start_batch = 0
            
        for i in range(start_batch, num_batches):
            print("Current Batch: "+str(i+1)+'/'+ str(num_batches))
            start = i * batch_size
            end = (i + 1) * batch_size if (i + 1) * batch_size < len(df) else len(df)
            df_batch = df.iloc[start:end]

            result = df_batch.pipe(self.generate_features, features=features)
            result.to_csv(csv_file, mode='a', index=False, header=i==0)
            with open(batch_file, 'w') as f:
                f.write(str(i))
                
    
    def generate_features_batch(self, df, features, batch_size=100000):

        nbatches = int(np.ceil(df.shape[0] / batch_size))
        print("Number of batches :", nbatches)
        feature_df = pd.DataFrame()

        for i in tqdm(list(range(nbatches))):
            batch_df = df.head((i + 1) * batch_size).tail(batch_size)
            batch_feat = batch_df.pipe(self.generate_features, features=features)
            #batch_feat = feature_engineering.post_process(batch_feat)
            feature_df = pd.concat([feature_df, batch_feat])
            print("Batch ", i + 1, ":  Done")

        return feature_df
    
    
    def generate_features_batch_csv(self, df, features, batch_size=40000):

        nbatches = int(np.ceil(df.shape[0] / batch_size))
        print("Number of batches :", nbatches)
        feature_df = pd.DataFrame()

        for i in tqdm(list(range(nbatches))):
            start=time.time()
            batch_df = df.head((i + 1) * batch_size).tail(batch_size)
            batch_feat = batch_df.pipe(self.generate_features, features=features)
            batch_feat = feature_engineering.post_process(batch_feat)
            fdf = batch_feat[[
                        'feature_lookup_date', 'job_id','developer_id', 
                        'interview_score', 'atleast_1yoe_ratio', 'mean_relevant_mcq_pct',
                        'mean_mcq_pct', 'max_skill_yoe', 'max_relevant_mcq_pct',
                        'min_relevant_mcq_pct', 'sum_relevant_proj_words', 'atleast_2yoe_ratio',
                        'atleast_3yoe_ratio', 'starts_in_weeks', 'hourly_rate', 'seniority_avg',
                        'max_mcq_pct', 'ti_acc_score', 'ti_lci_score', 'ti_ooo_score',
                        'cosine_similarity_job', 'cosine_similarity_query',
                        'cosine_similarity_query_ft', 'cosine_similarity_job_ft'
            ]]
            #feature_df = pd.concat([feature_df, batch_feat])
            fdf.to_csv("/hfeatures/file_"+i+".csv")
            print("Batch ", i + 1, ":  Done | Time taken", time.time() - start)

        return feature_df


    def generate_features_batch_bq(self, df, features, batch_size=100000):

        project_id = 'turing-dev-337819'
        dataset_id = 'product_ds_supply'
        table_id = 'temp_' + datetime.strptime(backfill_date, "%Y-%m-%d").strftime("%d_%m_%Y") + '_forecasted_q4_v0_FS'

        nbatches = int(np.ceil(df.shape[0] / batch_size))
        print("Number of batches :", nbatches)
        feature_df = pd.DataFrame()

        for i in tqdm(list(range(nbatches))):
            start=time.time()
            batch_df = df.head((i + 1) * batch_size).tail(batch_size)
            batch_feat = batch_df.pipe(self.generate_features, features=features)
            print("Batch ", i + 1, ":  S-PP | Time taken", time.time() - start)
            #batch_feat = feature_engineering.post_process(batch_feat)
            fdf = batch_feat[[
                        'feature_lookup_date', 'tupleId','job_id','developer_id', 
                        'interview_score', 'atleast_1yoe_ratio', 'mean_relevant_mcq_pct',
                        'mean_mcq_pct', 'max_skill_yoe', 'max_relevant_mcq_pct',
                        'min_relevant_mcq_pct', 'sum_relevant_proj_words', 'atleast_2yoe_ratio',
                        'atleast_3yoe_ratio', 'starts_in_weeks', 'hourly_rate', 'seniority_avg',
                        'max_mcq_pct', 'ti_acc_score', 'ti_lci_score', 'ti_ooo_score',
                        'cosine_similarity_job', 'cosine_similarity_query',
                        'cosine_similarity_query_ft', 'cosine_similarity_job_ft'
            ]]
            #feature_df = pd.concat([feature_df, batch_feat])

            fdf['tupleId'] = fdf['tupleId'].astype(str)
            fdf['job_id'] = fdf['job_id'].astype(int)
            fdf['developer_id'] = fdf['developer_id'].astype(int)
            fdf['interview_score'] = fdf['interview_score'].astype(str)
            fdf['atleast_1yoe_ratio'] = fdf['atleast_1yoe_ratio'].astype(str)
            fdf['mean_relevant_mcq_pct'] = fdf['mean_relevant_mcq_pct'].astype(str)
            fdf['mean_mcq_pct'] = fdf['mean_mcq_pct'].astype(str)
            fdf['max_skill_yoe'] = fdf['max_skill_yoe'].astype(str)
            fdf['max_relevant_mcq_pct'] = fdf['max_relevant_mcq_pct'].astype(str)
            fdf['min_relevant_mcq_pct'] = fdf['min_relevant_mcq_pct'].astype(str)
            fdf['sum_relevant_proj_words'] = fdf['sum_relevant_proj_words'].astype(str)
            fdf['atleast_2yoe_ratio'] = fdf['atleast_2yoe_ratio'].astype(str)
            fdf['atleast_3yoe_ratio'] = fdf['atleast_3yoe_ratio'].astype(str)
            fdf['starts_in_weeks'] = fdf['starts_in_weeks'].astype(str)
            fdf['hourly_rate'] = fdf['hourly_rate'].astype(str)
            fdf['seniority_avg'] = fdf['seniority_avg'].astype(str)
            fdf['max_mcq_pct'] = fdf['max_mcq_pct'].astype(str)
            fdf['ti_acc_score'] = fdf['ti_acc_score'].astype(str)
            fdf['ti_lci_score'] = fdf['ti_lci_score'].astype(str)
            fdf['ti_ooo_score'] = fdf['ti_ooo_score'].astype(str)
            fdf['cosine_similarity_job'] = fdf['cosine_similarity_job'].astype(str)
            fdf['cosine_similarity_query'] = fdf['cosine_similarity_query'].astype(str)
            fdf['cosine_similarity_query_ft'] = fdf['cosine_similarity_query_ft'].astype(str)
            fdf['cosine_similarity_job_ft'] = fdf['cosine_similarity_job_ft'].astype(str)
            

            pandas_gbq.to_gbq(fdf, f'{dataset_id}.{table_id}', project_id=project_id, if_exists='append')
            print("Batch ", i + 1, ":  Done | Time taken", time.time() - start)

        return feature_df

# %%
outcome_pairs_df.head()
# Out:
#     tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0  11836_11   11836       3784659          2023-11-29  [{114}, {189}]
# 1  11836_11   11836       1287973          2023-11-29  [{114}, {189}]
# 2  11836_11   11836       1868788          2023-11-29  [{114}, {189}]
# 3  11836_11   11836       3555220          2023-11-29  [{114}, {189}]
# 4  11836_11   11836       2060045          2023-11-29  [{114}, {189}]
#
#               challenge_ids            keywords   timestamp
# 0  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 1  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 2  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 3  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29
# 4  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]  2023-11-29

# %%
from datetime import datetime, timezone
outcome_pairs_df['timestamp'] = pd.to_datetime(datetime.now()).tz_localize(timezone.utc)

# %%
outcome_pairs_df.head()
# Out:
#     tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0  11836_11   11836       3784659          2023-11-29  [{114}, {189}]
# 1  11836_11   11836       1287973          2023-11-29  [{114}, {189}]
# 2  11836_11   11836       1868788          2023-11-29  [{114}, {189}]
# 3  11836_11   11836       3555220          2023-11-29  [{114}, {189}]
# 4  11836_11   11836       2060045          2023-11-29  [{114}, {189}]
#
#               challenge_ids            keywords  \
# 0  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 1  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 2  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 3  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 4  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
#
#                          timestamp
# 0 2023-11-30 12:22:38.916709+00:00
# 1 2023-11-30 12:22:38.916709+00:00
# 2 2023-11-30 12:22:38.916709+00:00
# 3 2023-11-30 12:22:38.916709+00:00
# 4 2023-11-30 12:22:38.916709+00:00

# %%
# No travel back, you can change timestamp to anything you want as long as you work within 2023

objectFeatures = VAIFeatureGenerator()
outcome_features = objectFeatures.generate_features_batch(outcome_pairs_df, features)
# Out:
# Number of batches : 26
#   0%|          | 0/26 [00:00<?, ?it/s]
# 11-30-2023 12:22:47 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:22:47 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:22:47 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:22:56 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813034
# 11-30-2023 12:22:57 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880826
# 11-30-2023 12:22:58 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206200723
# 11-30-2023 12:23:03 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:23:04 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:24:40 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:24:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 243.72067999839783
# Batch  1 :  Done
# 11-30-2023 12:26:51 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:26:51 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:26:56 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:27:06 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812992
# 11-30-2023 12:27:07 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880795
# 11-30-2023 12:27:08 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206437610
# 11-30-2023 12:27:12 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:27:13 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:28:41 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:28:43 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 217.06816697120667
# Batch  2 :  Done
# 11-30-2023 12:30:28 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:30:28 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:30:28 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:30:36 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812908
# 11-30-2023 12:30:37 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880733
# 11-30-2023 12:30:38 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206326367
# 11-30-2023 12:30:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:30:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:32:21 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:32:23 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 237.390704870224
# Batch  3 :  Done
# 11-30-2023 12:34:26 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:34:26 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:34:27 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:34:35 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880857
# 11-30-2023 12:34:35 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813076
# 11-30-2023 12:34:37 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206069213
# 11-30-2023 12:34:40 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:34:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:36:16 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:36:18 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 263.3847110271454
# Batch  4 :  Done
# 11-30-2023 12:38:50 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:38:50 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:38:51 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:38:59 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880795
# 11-30-2023 12:38:59 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812992
# 11-30-2023 12:38:59 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205814333
# 11-30-2023 12:39:04 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:39:06 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:40:30 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:40:32 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 248.33459281921387
# Batch  5 :  Done
# 11-30-2023 12:42:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:42:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:42:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:43:09 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880857
# 11-30-2023 12:43:10 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205653641
# 11-30-2023 12:43:13 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813034
# 11-30-2023 12:43:13 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:43:19 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:45:00 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:45:02 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 254.34684920310974
# Batch  6 :  Done
# 11-30-2023 12:47:14 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:47:14 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:47:15 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:47:23 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880702
# 11-30-2023 12:47:23 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812866
# 11-30-2023 12:47:27 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:47:28 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:48:19 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206168077
# 11-30-2023 12:49:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:50:01 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 294.23573780059814
# Batch  7 :  Done
# 11-30-2023 12:52:09 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:52:09 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:52:09 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:52:17 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880764
# 11-30-2023 12:52:17 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812950
# 11-30-2023 12:52:18 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206152349
# 11-30-2023 12:52:21 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:52:23 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:53:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:53:44 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 235.3407759666443
# Batch  8 :  Done
# 11-30-2023 12:56:05 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 12:56:05 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:56:05 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 12:56:15 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812992
# 11-30-2023 12:56:15 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880795
# 11-30-2023 12:56:16 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206188463
# 11-30-2023 12:56:20 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 12:56:21 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 12:57:47 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 12:57:49 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 233.24324321746826
# Batch  9 :  Done
# 11-30-2023 12:59:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 12:59:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:00:00 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:00:09 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880857
# 11-30-2023 13:00:09 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813076
# 11-30-2023 13:00:10 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206077205
# 11-30-2023 13:00:14 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:00:15 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:01:33 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:01:35 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 240.19218397140503
# Batch  10 :  Done
# 11-30-2023 13:04:00 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:04:00 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:04:00 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:04:09 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880733
# 11-30-2023 13:04:09 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812908
# 11-30-2023 13:04:11 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206519547
# 11-30-2023 13:04:13 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:04:15 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:05:57 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:05:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 258.5996391773224
# Batch  11 :  Done
# 11-30-2023 13:08:19 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:08:20 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:08:20 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:08:29 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880764
# 11-30-2023 13:08:31 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812908
# 11-30-2023 13:08:32 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206620617
# 11-30-2023 13:08:34 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:08:37 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:10:19 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:10:21 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 264.8511517047882
# Batch  12 :  Done
# 11-30-2023 13:12:45 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:12:45 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:12:46 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:12:54 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880733
# 11-30-2023 13:12:56 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206256830
# 11-30-2023 13:12:57 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812908
# 11-30-2023 13:12:59 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:13:03 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:14:22 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:14:24 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 218.95163106918335
# Batch  13 :  Done
# 11-30-2023 13:16:24 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:16:24 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:16:25 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:16:34 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880764
# 11-30-2023 13:16:35 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812950
# 11-30-2023 13:16:35 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206439821
# 11-30-2023 13:16:38 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:16:41 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:18:15 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:18:17 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 239.91712522506714
# Batch  14 :  Done
# 11-30-2023 13:20:25 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:20:25 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:20:26 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:20:35 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812950
# 11-30-2023 13:20:37 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205823745
# 11-30-2023 13:20:37 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880764
# 11-30-2023 13:20:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:20:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:22:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:22:44 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 296.2531409263611
# Batch  15 :  Done
# 11-30-2023 13:25:23 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:25:23 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:25:23 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:25:33 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812992
# 11-30-2023 13:25:33 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206314033
# 11-30-2023 13:25:34 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880795
# 11-30-2023 13:25:38 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:25:41 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:27:11 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:27:13 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 250.6667799949646
# Batch  16 :  Done
# 11-30-2023 13:29:34 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:29:34 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:29:35 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:29:43 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880795
# 11-30-2023 13:29:45 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812992
# 11-30-2023 13:29:45 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206157347
# 11-30-2023 13:29:48 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:29:51 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:31:11 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:31:13 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 250.66935396194458
# Batch  17 :  Done
# 11-30-2023 13:33:46 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:33:46 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:33:47 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:33:56 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813748
# 11-30-2023 13:33:57 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416881353
# 11-30-2023 13:33:58 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206314213
# 11-30-2023 13:34:02 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:34:03 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:35:30 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:35:32 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 305.1920280456543
# Batch  18 :  Done
# 11-30-2023 13:38:53 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:38:53 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:38:53 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:39:02 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813832
# 11-30-2023 13:39:02 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206072379
# 11-30-2023 13:39:03 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416881415
# 11-30-2023 13:39:08 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:39:09 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:40:25 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:40:27 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 323.054381608963
# Batch  19 :  Done
# 11-30-2023 13:44:17 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:44:17 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:44:18 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:44:26 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880733
# 11-30-2023 13:44:29 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206310009
# 11-30-2023 13:44:30 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812908
# 11-30-2023 13:44:31 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:44:37 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:46:31 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:46:33 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 284.6236877441406
# Batch  20 :  Done
# 11-30-2023 13:49:03 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:49:03 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:49:04 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:49:13 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813874
# 11-30-2023 13:49:14 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416881446
# 11-30-2023 13:49:15 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205999788
# 11-30-2023 13:49:18 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:49:20 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:50:43 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:50:45 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 344.92325496673584
# Batch  21 :  Done
# 11-30-2023 13:54:49 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 13:54:49 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 13:54:50 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 13:54:59 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813454
# 11-30-2023 13:55:00 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416881136
# 11-30-2023 13:55:04 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 13:55:06 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 13:56:25 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205835756
# 11-30-2023 13:58:06 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 13:58:08 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 374.0841245651245
# Batch  22 :  Done
# 11-30-2023 14:01:05 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 14:01:05 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 14:01:05 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 14:01:16 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261812950
# 11-30-2023 14:01:17 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416880795
# 11-30-2023 14:01:18 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205968196
# 11-30-2023 14:01:23 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 14:01:23 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 14:02:47 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 14:02:49 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 246.33607983589172
# Batch  23 :  Done
# 11-30-2023 14:05:12 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 14:05:12 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 14:05:13 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 14:05:22 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416881043
# 11-30-2023 14:05:23 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813328
# 11-30-2023 14:05:24 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205979002
# 11-30-2023 14:05:27 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 14:05:30 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 14:06:55 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 14:06:57 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 275.03474736213684
# Batch  24 :  Done
# 11-30-2023 14:09:48 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 14:09:48 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 14:09:49 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 14:09:59 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416881353
# 11-30-2023 14:10:01 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525206007148
# 11-30-2023 14:10:01 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261813748
# 11-30-2023 14:10:03 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 14:10:07 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 14:11:42 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 14:11:44 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 325.9893796443939
# Batch  25 :  Done
# 11-30-2023 14:15:15 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: developer
# 11-30-2023 14:15:15 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: job
# 11-30-2023 14:15:16 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Started fetching features for entity: query
# 11-30-2023 14:15:26 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 3416881818
# 11-30-2023 14:15:27 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 261814336
# 11-30-2023 14:15:27 - BQ_FEATURE_GENERATOR - INFO :: Total bytes to be processed: 525205985789
# 11-30-2023 14:15:33 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: job
# 11-30-2023 14:15:33 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: query
# 11-30-2023 14:17:15 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Finished fetching features for entity: developer
# 11-30-2023 14:17:17 - HISTORICAL_FEATURE_STORE_ACCESSOR - INFO :: Using /tmp instead of /dev/shm because shm only has {total_size_mb} MB available.
# Time taken 405.356693983078
# Batch  26 :  Done

# %%
outcome_features
# Out:
#          tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0       11836_11   11836           387          2023-11-29  [{114}, {189}]
# 1       11836_11   11836          2499          2023-11-29  [{114}, {189}]
# 2       11836_11   11836          2883          2023-11-29  [{114}, {189}]
# 3       11836_11   11836          4389          2023-11-29  [{114}, {189}]
# 4       11836_11   11836          5362          2023-11-29  [{114}, {189}]
# ...          ...     ...           ...                 ...             ...
# 99995  15609_314   15609       3825452          2023-11-29          [{16}]
# 99996  15609_314   15609       3827630          2023-11-29          [{16}]
# 99997  15609_314   15609       3827821          2023-11-29          [{16}]
# 99998  15609_314   15609       3829566          2023-11-29          [{16}]
# 99999  15609_314   15609       3831389          2023-11-29          [{16}]
#
#                   challenge_ids             keywords  \
# 0      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 1      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 2      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 3      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 4      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# ...                         ...                  ...
# 99995                   [{135}]  [[iOS Development]]
# 99996                   [{135}]  [[iOS Development]]
# 99997                   [{135}]  [[iOS Development]]
# 99998                   [{135}]  [[iOS Development]]
# 99999                   [{135}]  [[iOS Development]]
#
#                              timestamp  interview_score  atleast_1yoe_ratio  \
# 0     2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# 1     2023-11-30 12:22:38.916709+00:00              5.0                 1.0
# 2     2023-11-30 12:22:38.916709+00:00              5.0                 1.0
# 3     2023-11-30 12:22:38.916709+00:00             10.0                 1.0
# 4     2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# ...                                ...              ...                 ...
# 99995 2023-11-30 12:22:38.916709+00:00              NaN                 0.0
# 99996 2023-11-30 12:22:38.916709+00:00              8.0                 0.0
# 99997 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 99998 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 99999 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
#
#        ...  hourly_rate  seniority_avg  max_mcq_pct  ti_acc_score  \
# 0      ...          NaN       2.856666    69.714711           7.0
# 1      ...      6.24299       3.800834   100.000000           5.0
# 2      ...     19.11900       3.533334    78.188259           5.0
# 3      ...     12.40620       4.490000   100.000000          10.0
# 4      ...     45.00000       4.057500    98.513149           NaN
# ...    ...          ...            ...          ...           ...
# 99995  ...          NaN       3.545000    87.892108           NaN
# 99996  ...          NaN       4.345834    91.318336           8.0
# 99997  ...          NaN       3.522500    63.640480           5.0
# 99998  ...          NaN       4.300834    93.899486           5.0
# 99999  ...          NaN       3.545834          NaN           5.0
#
#        ti_lci_score  ti_ooo_score  cosine_similarity_job  \
# 0               NaN           NaN              -0.884535
# 1               NaN           NaN              -0.902550
# 2               NaN           NaN              -0.908211
# 3               NaN           NaN              -0.800924
# 4               7.0           NaN              -0.901845
# ...             ...           ...                    ...
# 99995           NaN           NaN                    NaN
# 99996           NaN           NaN                    NaN
# 99997           NaN           NaN                    NaN
# 99998           NaN           NaN                    NaN
# 99999           NaN           NaN                    NaN
#
#        cosine_similarity_query  cosine_similarity_query_ft  \
# 0                    -0.484625                   -0.038759
# 1                    -0.523804                    0.178803
# 2                    -0.545369                    0.209851
# 3                    -0.406972                   -0.021816
# 4                    -0.519246                    0.011571
# ...                        ...                         ...
# 99995                      NaN                         NaN
# 99996                      NaN                         NaN
# 99997                      NaN                         NaN
# 99998                      NaN                         NaN
# 99999                      NaN                         NaN
#
#        cosine_similarity_job_ft
# 0                      0.090793
# 1                      0.280685
# 2                      0.326563
# 3                      0.204157
# 4                      0.184234
# ...                         ...
# 99995                       NaN
# 99996                       NaN
# 99997                       NaN
# 99998                       NaN
# 99999                       NaN
#
# [2600000 rows x 29 columns]

# %%
outcome_pairs_df.head()
# Out:
#     tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0  11836_11   11836       3784659          2023-11-29  [{114}, {189}]
# 1  11836_11   11836       1287973          2023-11-29  [{114}, {189}]
# 2  11836_11   11836       1868788          2023-11-29  [{114}, {189}]
# 3  11836_11   11836       3555220          2023-11-29  [{114}, {189}]
# 4  11836_11   11836       2060045          2023-11-29  [{114}, {189}]
#
#               challenge_ids            keywords  \
# 0  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 1  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 2  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 3  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 4  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
#
#                          timestamp
# 0 2023-11-30 12:22:38.916709+00:00
# 1 2023-11-30 12:22:38.916709+00:00
# 2 2023-11-30 12:22:38.916709+00:00
# 3 2023-11-30 12:22:38.916709+00:00
# 4 2023-11-30 12:22:38.916709+00:00

# %%
outcome_features.dtypes
# Out:
# tupleId                                    object
# job_id                                      int64
# developer_id                                int64
# feature_lookup_date                        object
# skill_ids                                  object
# challenge_ids                              object
# keywords                                   object
# timestamp                     datetime64[ns, UTC]
# interview_score                           float64
# atleast_1yoe_ratio                        float64
# mean_relevant_mcq_pct                     float64
# mean_mcq_pct                              float64
# max_skill_yoe                             float64
# max_relevant_mcq_pct                      float64
# min_relevant_mcq_pct                      float64
# sum_relevant_proj_words                     int32
# atleast_2yoe_ratio                        float64
# atleast_3yoe_ratio                        float64
# starts_in_weeks                           float64
# hourly_rate                               float64
# seniority_avg                             float64
# max_mcq_pct                               float64
# ti_acc_score                              float64
# ti_lci_score                              float64
# ti_ooo_score                              float64
# cosine_similarity_job                     float64
# cosine_similarity_query                   float64
# cosine_similarity_query_ft                float64
# cosine_similarity_job_ft                  float64
# dtype: object

# %%
fdf = outcome_features.copy()


fdf['tupleId'] = fdf['tupleId'].astype(str)
fdf['job_id'] = fdf['job_id'].astype(int)
fdf['developer_id'] = fdf['developer_id'].astype(int)
fdf['interview_score'] = fdf['interview_score'].astype(float)
fdf['atleast_1yoe_ratio'] = fdf['atleast_1yoe_ratio'].astype(float)
fdf['mean_relevant_mcq_pct'] = fdf['mean_relevant_mcq_pct'].astype(float)
fdf['mean_mcq_pct'] = fdf['mean_mcq_pct'].astype(float)
fdf['max_skill_yoe'] = fdf['max_skill_yoe'].astype(float)
fdf['max_relevant_mcq_pct'] = fdf['max_relevant_mcq_pct'].astype(float)
fdf['min_relevant_mcq_pct'] = fdf['min_relevant_mcq_pct'].astype(float)
fdf['sum_relevant_proj_words'] = fdf['sum_relevant_proj_words'].astype(float)
fdf['atleast_2yoe_ratio'] = fdf['atleast_2yoe_ratio'].astype(float)
fdf['atleast_3yoe_ratio'] = fdf['atleast_3yoe_ratio'].astype(float)
fdf['starts_in_weeks'] = pd.to_numeric(fdf['starts_in_weeks'], errors='coerce').astype(float)
fdf['hourly_rate'] = fdf['hourly_rate'].astype(float)
fdf['seniority_avg'] = fdf['seniority_avg'].astype(float)
fdf['max_mcq_pct'] = fdf['max_mcq_pct'].astype(float)
fdf['ti_acc_score'] = fdf['ti_acc_score'].astype(float)
fdf['ti_lci_score'] = fdf['ti_lci_score'].astype(float)
fdf['ti_ooo_score'] = fdf['ti_ooo_score'].astype(float)
fdf['cosine_similarity_job'] = fdf['cosine_similarity_job'].astype(float)
fdf['cosine_similarity_query'] = fdf['cosine_similarity_query'].astype(float)
fdf['cosine_similarity_query_ft'] = fdf['cosine_similarity_query_ft'].astype(float)
fdf['cosine_similarity_job_ft'] = fdf['cosine_similarity_job_ft'].astype(float)


outcome_features = fdf.copy()

# %%
outcome_features.columns
# Out:
# Index(['tupleId', 'job_id', 'developer_id', 'feature_lookup_date', 'skill_ids',
#        'challenge_ids', 'keywords', 'timestamp', 'interview_score',
#        'atleast_1yoe_ratio', 'mean_relevant_mcq_pct', 'mean_mcq_pct',
#        'max_skill_yoe', 'max_relevant_mcq_pct', 'min_relevant_mcq_pct',
#        'sum_relevant_proj_words', 'atleast_2yoe_ratio', 'atleast_3yoe_ratio',
#        'starts_in_weeks', 'hourly_rate', 'seniority_avg', 'max_mcq_pct',
#        'ti_acc_score', 'ti_lci_score', 'ti_ooo_score', 'cosine_similarity_job',
#        'cosine_similarity_query', 'cosine_similarity_query_ft',
#        'cosine_similarity_job_ft'],
#       dtype='object')

# %%
outcome_features.head(5)
# Out:
#     tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0  11836_11   11836           387          2023-11-29  [{114}, {189}]
# 1  11836_11   11836          2499          2023-11-29  [{114}, {189}]
# 2  11836_11   11836          2883          2023-11-29  [{114}, {189}]
# 3  11836_11   11836          4389          2023-11-29  [{114}, {189}]
# 4  11836_11   11836          5362          2023-11-29  [{114}, {189}]
#
#               challenge_ids            keywords  \
# 0  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 1  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 2  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 3  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 4  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
#
#                          timestamp  interview_score  atleast_1yoe_ratio  ...  \
# 0 2023-11-30 12:22:38.916709+00:00              7.0                 1.0  ...
# 1 2023-11-30 12:22:38.916709+00:00              5.0                 1.0  ...
# 2 2023-11-30 12:22:38.916709+00:00              5.0                 1.0  ...
# 3 2023-11-30 12:22:38.916709+00:00             10.0                 1.0  ...
# 4 2023-11-30 12:22:38.916709+00:00              7.0                 1.0  ...
#
#    hourly_rate  seniority_avg  max_mcq_pct  ti_acc_score  ti_lci_score  \
# 0          NaN       2.856666    69.714711           7.0           NaN
# 1      6.24299       3.800834   100.000000           5.0           NaN
# 2     19.11900       3.533334    78.188259           5.0           NaN
# 3     12.40620       4.490000   100.000000          10.0           NaN
# 4     45.00000       4.057500    98.513149           NaN           7.0
#
#    ti_ooo_score  cosine_similarity_job  cosine_similarity_query  \
# 0           NaN              -0.884535                -0.484625
# 1           NaN              -0.902550                -0.523804
# 2           NaN              -0.908211                -0.545369
# 3           NaN              -0.800924                -0.406972
# 4           NaN              -0.901845                -0.519246
#
#    cosine_similarity_query_ft  cosine_similarity_job_ft
# 0                   -0.038759                  0.090793
# 1                    0.178803                  0.280685
# 2                    0.209851                  0.326563
# 3                   -0.021816                  0.204157
# 4                    0.011571                  0.184234
#
# [5 rows x 29 columns]

# %%
all_outcomes.rename(columns = {'Extraction_Date' : 'feature_lookup_date'}, inplace = True)
all_outcomes = all_outcomes.merge(outcome_features,on=['job_id','developer_id','feature_lookup_date'],how='left')
all_outcomes.shape
# Out:
# (2775758, 30)

# %%
all_outcomes = outcome_features.copy()

# %%
all_outcomes = all_outcomes.drop_duplicates(subset=["feature_lookup_date" ,"developer_id", "job_id", "tupleId"])
all_outcomes.shape
# Out:
# (2598122, 29)

# %% [markdown]
# ### Post-Processing
# Generate the ranking score for the respective TupleID & Developer ID pairs.

# %%
from ranking_utility.config import PredictionType
all_outcomes = feature_engineering.post_process(all_outcomes, prediction_type=PredictionType.OFFLINE)

# %%
outcome_features["sum_relevant_proj_words"] = outcome_features["sum_relevant_proj_words"].astype(float)

# %%
all_outcomes = outcome_features.copy()

# %% [markdown]
# ### Model: HM Discernment

# %%
model_gbdtv23 = None
threshold = 0.000646
with open(
    "../learning_better_ranking/vertex_ai_models/models/gbdt_ranker_v23/search2start_gbdt_v23.pkl",
    "rb",
) as fp:
    model_gbdtv23 = pickle.load(fp)

# %%
features_columns = ['starts_in_weeks',
 'hourly_rate',
 'atleast_2yoe_ratio',
 'mean_mcq_pct',
 'max_skill_yoe',
 'atleast_3yoe_ratio',
 'seniority_avg',
 'min_relevant_mcq_pct',
 'max_relevant_mcq_pct',
 'sum_relevant_proj_words',
 'atleast_1yoe_ratio',
 'max_mcq_pct',
 'ti_ooo_score',
 'ti_lci_score',
 'ti_acc_score',
 'cosine_similarity_query_ft',
 'cosine_similarity_job_ft']

# %%
all_outcomes[f'model_ttf_score'] = model_gbdtv23.predict(all_outcomes[features_columns])

all_outcomes['model_restrict'] =(
        (all_outcomes.ti_ooo_score < 5)
        | (all_outcomes.mean_mcq_pct < 61)
        | (all_outcomes.min_relevant_mcq_pct < 40)
)

all_outcomes['model_backfill_score'] =  np.where(all_outcomes['model_restrict'] == False, all_outcomes['model_ttf_score'], -1)
all_outcomes['hm_satisfy'] =  np.where(all_outcomes['model_backfill_score'] >= threshold, 1, 0)
all_outcomes
# Out:
#          tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0       11836_11   11836           387          2023-11-29  [{114}, {189}]
# 1       11836_11   11836          2499          2023-11-29  [{114}, {189}]
# 2       11836_11   11836          2883          2023-11-29  [{114}, {189}]
# 3       11836_11   11836          4389          2023-11-29  [{114}, {189}]
# 4       11836_11   11836          5362          2023-11-29  [{114}, {189}]
# ...          ...     ...           ...                 ...             ...
# 99995  15609_314   15609       3825452          2023-11-29          [{16}]
# 99996  15609_314   15609       3827630          2023-11-29          [{16}]
# 99997  15609_314   15609       3827821          2023-11-29          [{16}]
# 99998  15609_314   15609       3829566          2023-11-29          [{16}]
# 99999  15609_314   15609       3831389          2023-11-29          [{16}]
#
#                   challenge_ids             keywords  \
# 0      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 1      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 2      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 3      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 4      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# ...                         ...                  ...
# 99995                   [{135}]  [[iOS Development]]
# 99996                   [{135}]  [[iOS Development]]
# 99997                   [{135}]  [[iOS Development]]
# 99998                   [{135}]  [[iOS Development]]
# 99999                   [{135}]  [[iOS Development]]
#
#                              timestamp  interview_score  atleast_1yoe_ratio  \
# 0     2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# 1     2023-11-30 12:22:38.916709+00:00              5.0                 1.0
# 2     2023-11-30 12:22:38.916709+00:00              5.0                 1.0
# 3     2023-11-30 12:22:38.916709+00:00             10.0                 1.0
# 4     2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# ...                                ...              ...                 ...
# 99995 2023-11-30 12:22:38.916709+00:00              NaN                 0.0
# 99996 2023-11-30 12:22:38.916709+00:00              8.0                 0.0
# 99997 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 99998 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 99999 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
#
#        ...  ti_lci_score  ti_ooo_score  cosine_similarity_job  \
# 0      ...           NaN           NaN              -0.884535
# 1      ...           NaN           NaN              -0.902550
# 2      ...           NaN           NaN              -0.908211
# 3      ...           NaN           NaN              -0.800924
# 4      ...           7.0           NaN              -0.901845
# ...    ...           ...           ...                    ...
# 99995  ...           NaN           NaN                    NaN
# 99996  ...           NaN           NaN                    NaN
# 99997  ...           NaN           NaN                    NaN
# 99998  ...           NaN           NaN                    NaN
# 99999  ...           NaN           NaN                    NaN
#
#        cosine_similarity_query  cosine_similarity_query_ft  \
# 0                    -0.484625                   -0.038759
# 1                    -0.523804                    0.178803
# 2                    -0.545369                    0.209851
# 3                    -0.406972                   -0.021816
# 4                    -0.519246                    0.011571
# ...                        ...                         ...
# 99995                      NaN                         NaN
# 99996                      NaN                         NaN
# 99997                      NaN                         NaN
# 99998                      NaN                         NaN
# 99999                      NaN                         NaN
#
#        cosine_similarity_job_ft  model_ttf_score  model_restrict  \
# 0                      0.090793         0.000006           False
# 1                      0.280685         0.000513            True
# 2                      0.326563         0.000387            True
# 3                      0.204157         0.000132           False
# 4                      0.184234         0.000540           False
# ...                         ...              ...             ...
# 99995                       NaN         0.000085           False
# 99996                       NaN         0.000052           False
# 99997                       NaN         0.000043            True
# 99998                       NaN         0.000117           False
# 99999                       NaN         0.000002           False
#
#        model_backfill_score  hm_satisfy
# 0                  0.000006           0
# 1                 -1.000000           0
# 2                 -1.000000           0
# 3                  0.000132           0
# 4                  0.000540           0
# ...                     ...         ...
# 99995              0.000085           0
# 99996              0.000052           0
# 99997             -1.000000           0
# 99998              0.000117           0
# 99999              0.000002           0
#
# [2600000 rows x 33 columns]

# %% [markdown]
# ### Hourly Rate Imputation
# Impute hourly rate for Non-HM developers who have 'NAN' as an input for this feature.

# %%
nhm = all_outcomes[all_outcomes.model_backfill_score < threshold]
nhm = nhm[nhm.hourly_rate.isna()]

# %%
nhm
# Out:
#          tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0       11836_11   11836           387          2023-11-29  [{114}, {189}]
# 7       11836_11   11836         11172          2023-11-29  [{114}, {189}]
# 22      11836_11   11836         63692          2023-11-29  [{114}, {189}]
# 29      11836_11   11836        109111          2023-11-29  [{114}, {189}]
# 33      11836_11   11836        116386          2023-11-29  [{114}, {189}]
# ...          ...     ...           ...                 ...             ...
# 99995  15609_314   15609       3825452          2023-11-29          [{16}]
# 99996  15609_314   15609       3827630          2023-11-29          [{16}]
# 99997  15609_314   15609       3827821          2023-11-29          [{16}]
# 99998  15609_314   15609       3829566          2023-11-29          [{16}]
# 99999  15609_314   15609       3831389          2023-11-29          [{16}]
#
#                   challenge_ids             keywords  \
# 0      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 7      [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 22     [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 29     [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# 33     [{128, 109, 432}, {565}]   [[SQL], [Tableau]]
# ...                         ...                  ...
# 99995                   [{135}]  [[iOS Development]]
# 99996                   [{135}]  [[iOS Development]]
# 99997                   [{135}]  [[iOS Development]]
# 99998                   [{135}]  [[iOS Development]]
# 99999                   [{135}]  [[iOS Development]]
#
#                              timestamp  interview_score  atleast_1yoe_ratio  \
# 0     2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# 7     2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# 22    2023-11-30 12:22:38.916709+00:00             10.0                 1.0
# 29    2023-11-30 12:22:38.916709+00:00              6.0                 1.0
# 33    2023-11-30 12:22:38.916709+00:00              8.0                 0.5
# ...                                ...              ...                 ...
# 99995 2023-11-30 12:22:38.916709+00:00              NaN                 0.0
# 99996 2023-11-30 12:22:38.916709+00:00              8.0                 0.0
# 99997 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 99998 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 99999 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
#
#        ...  ti_lci_score  ti_ooo_score  cosine_similarity_job  \
# 0      ...           NaN           NaN              -0.884535
# 7      ...           NaN           NaN              -0.887280
# 22     ...           NaN           NaN               0.908356
# 29     ...           NaN           NaN              -0.893872
# 33     ...           8.0           NaN              -0.895648
# ...    ...           ...           ...                    ...
# 99995  ...           NaN           NaN                    NaN
# 99996  ...           NaN           NaN                    NaN
# 99997  ...           NaN           NaN                    NaN
# 99998  ...           NaN           NaN                    NaN
# 99999  ...           NaN           NaN                    NaN
#
#        cosine_similarity_query  cosine_similarity_query_ft  \
# 0                    -0.484625                   -0.038759
# 7                    -0.484665                    0.143015
# 22                    0.590344                   -0.045763
# 29                   -0.498885                   -0.231007
# 33                   -0.511537                    0.171444
# ...                        ...                         ...
# 99995                      NaN                         NaN
# 99996                      NaN                         NaN
# 99997                      NaN                         NaN
# 99998                      NaN                         NaN
# 99999                      NaN                         NaN
#
#        cosine_similarity_job_ft  model_ttf_score  model_restrict  \
# 0                      0.090793         0.000006           False
# 7                      0.423837         0.000057            True
# 22                     0.351010         0.000046           False
# 29                    -0.266892         0.000017           False
# 33                     0.322384         0.000040           False
# ...                         ...              ...             ...
# 99995                       NaN         0.000085           False
# 99996                       NaN         0.000052           False
# 99997                       NaN         0.000043            True
# 99998                       NaN         0.000117           False
# 99999                       NaN         0.000002           False
#
#        model_backfill_score  hm_satisfy
# 0                  0.000006           0
# 7                 -1.000000           0
# 22                 0.000046           0
# 29                 0.000017           0
# 33                 0.000040           0
# ...                     ...         ...
# 99995              0.000085           0
# 99996              0.000052           0
# 99997             -1.000000           0
# 99998              0.000117           0
# 99999              0.000002           0
#
# [1080457 rows x 33 columns]

# %%
all_outcomes = nhm.copy()
all_outcomes.rename(columns = {'hourly_rate' : 'old_hourly_rate'}, inplace = True)
all_outcomes.shape
# Out:
# (1080457, 33)

# %% [markdown]
# ### Dev Rate Card
# We will be using the dev rate for imputing the rate

# %%
dev_geo_yoe = pd.io.gbq.read_gbq(
f"""

  With data_final as (select a.user_id as developer_id, b.role_type, c.country_group,
  case when a.years_of_experience < 3 then '[0-3)'
      when a.years_of_experience < 5 then '[3-5)'
      when a.years_of_experience < 7 then '[5-7)'
      when a.years_of_experience < 10 then '[7-10)'
      when a.years_of_experience < 14 then '[10-14)'
      Else '[14,+)' end as yoe_bucket
  from `turing-230020.raw.developer_detail` a
  left join `turing-230020.raw.ms2_job_role_type` b on a.role_type_id = b.id
  left join `turing-230020.curated.country_information` c on a.country_id = c.country_id
  )

  select a.developer_id, b.ub as hourly_rate from data_final a
  left join `turing-dev-337819.data_science.rate_card_v3_role_p12` b USING(country_group,role_type,yoe_bucket)
  where a.developer_id in ({', '.join(map(str, list(all_outcomes.developer_id.unique())))})
"""
,project_id='turing-230020')
dev_geo_yoe
# Out:
#        developer_id  hourly_rate
# 0           1235461    28.516670
# 1           1322574    20.602424
# 2           1409184    43.256821
# 3           2241742    20.815724
# 4           2411708    45.436427
# ...             ...          ...
# 40456       2859459    25.594702
# 40457       2493648    25.594702
# 40458       2558574    25.594702
# 40459       3656789    25.594702
# 40460       1597562    25.594702
#
# [40461 rows x 2 columns]

# %%
all_outcomes.head()
# Out:
#      tupleId  job_id  developer_id feature_lookup_date       skill_ids  \
# 0   11836_11   11836           387          2023-11-29  [{114}, {189}]
# 7   11836_11   11836         11172          2023-11-29  [{114}, {189}]
# 22  11836_11   11836         63692          2023-11-29  [{114}, {189}]
# 29  11836_11   11836        109111          2023-11-29  [{114}, {189}]
# 33  11836_11   11836        116386          2023-11-29  [{114}, {189}]
#
#                challenge_ids            keywords  \
# 0   [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 7   [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 22  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 29  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
# 33  [{128, 109, 432}, {565}]  [[SQL], [Tableau]]
#
#                           timestamp  interview_score  atleast_1yoe_ratio  ...  \
# 0  2023-11-30 12:22:38.916709+00:00              7.0                 1.0  ...
# 7  2023-11-30 12:22:38.916709+00:00              7.0                 1.0  ...
# 22 2023-11-30 12:22:38.916709+00:00             10.0                 1.0  ...
# 29 2023-11-30 12:22:38.916709+00:00              6.0                 1.0  ...
# 33 2023-11-30 12:22:38.916709+00:00              8.0                 0.5  ...
#
#     ti_lci_score  ti_ooo_score  cosine_similarity_job  \
# 0            NaN           NaN              -0.884535
# 7            NaN           NaN              -0.887280
# 22           NaN           NaN               0.908356
# 29           NaN           NaN              -0.893872
# 33           8.0           NaN              -0.895648
#
#     cosine_similarity_query  cosine_similarity_query_ft  \
# 0                 -0.484625                   -0.038759
# 7                 -0.484665                    0.143015
# 22                 0.590344                   -0.045763
# 29                -0.498885                   -0.231007
# 33                -0.511537                    0.171444
#
#     cosine_similarity_job_ft  model_ttf_score  model_restrict  \
# 0                   0.090793         0.000006           False
# 7                   0.423837         0.000057            True
# 22                  0.351010         0.000046           False
# 29                 -0.266892         0.000017           False
# 33                  0.322384         0.000040           False
#
#     model_backfill_score  hm_satisfy
# 0               0.000006           0
# 7              -1.000000           0
# 22              0.000046           0
# 29              0.000017           0
# 33              0.000040           0
#
# [5 rows x 33 columns]

# %%
all_outcomes = all_outcomes.merge(dev_geo_yoe[['developer_id', 'hourly_rate']], on='developer_id', how='left')

# %%
all_outcomes['job_id'] = all_outcomes['job_id'].astype(int)
all_outcomes['developer_id'] = all_outcomes['developer_id'].astype(int)

all_outcomes['starts_in_weeks'] = all_outcomes['starts_in_weeks'].astype(float)
all_outcomes['hourly_rate'] = all_outcomes['hourly_rate'].astype(float)
all_outcomes['atleast_2yoe_ratio'] = all_outcomes['atleast_2yoe_ratio'].astype(float)
all_outcomes['mean_mcq_pct'] = all_outcomes['mean_mcq_pct'].astype(float)
all_outcomes['max_skill_yoe'] = all_outcomes['max_skill_yoe'].astype(float)
all_outcomes['atleast_3yoe_ratio'] = all_outcomes['atleast_3yoe_ratio'].astype(float)
all_outcomes['seniority_avg'] = all_outcomes['seniority_avg'].astype(float)
all_outcomes['min_relevant_mcq_pct'] = all_outcomes['min_relevant_mcq_pct'].astype(float)
all_outcomes['max_relevant_mcq_pct'] = all_outcomes['max_relevant_mcq_pct'].astype(float)
all_outcomes['sum_relevant_proj_words'] = all_outcomes['sum_relevant_proj_words'].astype(float)
all_outcomes['atleast_1yoe_ratio'] = all_outcomes['atleast_1yoe_ratio'].astype(float)
all_outcomes['max_mcq_pct'] = all_outcomes['max_mcq_pct'].astype(float)
all_outcomes['ti_ooo_score'] = all_outcomes['ti_ooo_score'].astype(float)
all_outcomes['ti_lci_score'] = all_outcomes['ti_lci_score'].astype(float)
all_outcomes['ti_acc_score'] = all_outcomes['ti_acc_score'].astype(float)
all_outcomes['cosine_similarity_query_ft'] = all_outcomes['cosine_similarity_query_ft'].astype(float)
all_outcomes['cosine_similarity_job_ft'] = all_outcomes['cosine_similarity_job_ft'].astype(float)

all_outcomes = feature_engineering.post_process(all_outcomes, prediction_type=PredictionType.OFFLINE)

# %%
all_outcomes.columns
# Out:
# Index(['tupleId', 'job_id', 'developer_id', 'feature_lookup_date', 'timestamp',
#        'interview_score', 'atleast_1yoe_ratio', 'mean_relevant_mcq_pct',
#        'mean_mcq_pct', 'max_skill_yoe', 'max_relevant_mcq_pct',
#        'min_relevant_mcq_pct', 'sum_relevant_proj_words', 'atleast_2yoe_ratio',
#        'atleast_3yoe_ratio', 'starts_in_weeks', 'old_hourly_rate',
#        'seniority_avg', 'max_mcq_pct', 'ti_acc_score', 'ti_lci_score',
#        'ti_ooo_score', 'cosine_similarity_job', 'cosine_similarity_query',
#        'cosine_similarity_query_ft', 'cosine_similarity_job_ft',
#        'model_ttf_score', 'model_restrict', 'model_backfill_score',
#        'hm_satisfy', 'hourly_rate'],
#       dtype='object')

# %%
all_outcomes[f'model_ttf_score'] = model_gbdtv23.predict(all_outcomes[features_columns])

all_outcomes['model_restrict'] =(
        (all_outcomes.ti_ooo_score < 5)
        | (all_outcomes.mean_mcq_pct < 61)
        | (all_outcomes.min_relevant_mcq_pct < 40)
)

all_outcomes['model_backfill_score'] =  np.where(all_outcomes['model_restrict'] == False, all_outcomes['model_ttf_score'], -1)
all_outcomes['hm_satisfy'] =  np.where(all_outcomes['model_backfill_score'] >= threshold, 1, 0)
all_outcomes[['tupleId' ,'job_id', 'developer_id', 'model_backfill_score','hm_satisfy', 'hourly_rate']]
all_outcomes
# Out:
#            tupleId  job_id  developer_id feature_lookup_date  \
# 0         11836_11   11836           387          2023-11-29
# 1         11836_11   11836         11172          2023-11-29
# 2         11836_11   11836         63692          2023-11-29
# 3         11836_11   11836        109111          2023-11-29
# 4         11836_11   11836        116386          2023-11-29
# ...            ...     ...           ...                 ...
# 1080452  15609_314   15609       3825452          2023-11-29
# 1080453  15609_314   15609       3827630          2023-11-29
# 1080454  15609_314   15609       3827821          2023-11-29
# 1080455  15609_314   15609       3829566          2023-11-29
# 1080456  15609_314   15609       3831389          2023-11-29
#
#                                timestamp  interview_score  atleast_1yoe_ratio  \
# 0       2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# 1       2023-11-30 12:22:38.916709+00:00              7.0                 1.0
# 2       2023-11-30 12:22:38.916709+00:00             10.0                 1.0
# 3       2023-11-30 12:22:38.916709+00:00              6.0                 1.0
# 4       2023-11-30 12:22:38.916709+00:00              8.0                 0.5
# ...                                  ...              ...                 ...
# 1080452 2023-11-30 12:22:38.916709+00:00              NaN                 0.0
# 1080453 2023-11-30 12:22:38.916709+00:00              8.0                 0.0
# 1080454 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 1080455 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
# 1080456 2023-11-30 12:22:38.916709+00:00              5.0                 0.0
#
#          mean_relevant_mcq_pct  mean_mcq_pct  max_skill_yoe  ...  \
# 0                          NaN     69.714711            1.0  ...
# 1                    43.889588     34.770218            5.2  ...
# 2                    96.576155     77.489194            2.6  ...
# 3                          NaN     68.556524            1.0  ...
# 4                    91.363064     74.687276            1.0  ...
# ...                        ...           ...            ...  ...
# 1080452                    NaN     87.892108            0.0  ...
# 1080453                    NaN     87.528491            0.0  ...
# 1080454                    NaN     56.953118            0.0  ...
# 1080455                    NaN     93.899486            0.0  ...
# 1080456                    NaN           NaN            0.9  ...
#
#          ti_ooo_score  cosine_similarity_job  cosine_similarity_query  \
# 0                 NaN              -0.884535                -0.484625
# 1                 NaN              -0.887280                -0.484665
# 2                 NaN               0.908356                 0.590344
# 3                 NaN              -0.893872                -0.498885
# 4                 NaN              -0.895648                -0.511537
# ...               ...                    ...                      ...
# 1080452           NaN                    NaN                      NaN
# 1080453           NaN                    NaN                      NaN
# 1080454           NaN                    NaN                      NaN
# 1080455           NaN                    NaN                      NaN
# 1080456           NaN                    NaN                      NaN
#
#          cosine_similarity_query_ft  cosine_similarity_job_ft  \
# 0                         -0.038759                  0.090793
# 1                          0.143015                  0.423837
# 2                         -0.045763                  0.351010
# 3                         -0.231007                 -0.266892
# 4                          0.171444                  0.322384
# ...                             ...                       ...
# 1080452                         NaN                       NaN
# 1080453                         NaN                       NaN
# 1080454                         NaN                       NaN
# 1080455                         NaN                       NaN
# 1080456                         NaN                       NaN
#
#          model_ttf_score  model_restrict  model_backfill_score  hm_satisfy  \
# 0               0.000039           False              0.000039           0
# 1               0.000241            True             -1.000000           0
# 2               0.000116           False              0.000116           0
# 3               0.000075           False              0.000075           0
# 4               0.000366           False              0.000366           0
# ...                  ...             ...                   ...         ...
# 1080452         0.000364           False              0.000364           0
# 1080453         0.000154           False              0.000154           0
# 1080454         0.000195            True             -1.000000           0
# 1080455         0.000340           False              0.000340           0
# 1080456         0.000005           False              0.000005           0
#
#          hourly_rate
# 0          23.370596
# 1          44.643757
# 2          56.017462
# 3          40.082911
# 4          24.173153
# ...              ...
# 1080452    21.203692
# 1080453    28.040044
# 1080454    30.099260
# 1080455    35.868364
# 1080456    29.394012
#
# [1080457 rows x 31 columns]

# %%
import pandas_gbq
# Replace 'your_project_id', 'your_dataset_id', and 'your_table_id' with your actual values
project_id = 'turing-dev-337819'
dataset_id = 'pdsa'
table_id = 'phm_30_11'

# Insert the DataFrame into the BigQuery table

pandas_gbq.to_gbq(all_outcomes, f'{dataset_id}.{table_id}', project_id=project_id, if_exists='replace')
# Out:
# 100% 1/1 [00:00<00:00, 11491.24it/s]
